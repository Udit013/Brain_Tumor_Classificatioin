# %%
# Necessary imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image

from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score,classification_report
import numpy as np
import os
import cv2
from google.colab import files, drive
from IPython.display import clear_output
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %%
def load_dataset():
    if os.path.exists('/content/brain-tumor-mri-dataset'):
        return

    uploaded = files.upload()

    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes.'.format(name=fn, length=len(uploaded[fn])))

    # !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
    # !kaggle datasets download -d masoudnickparvar/brain-tumor-mri-dataset
    # !mkdir brain-tumor-mri-dataset
    # !unzip brain-tumor-mri-dataset.zip -d ./brain-tumor-mri-dataset
    clear_output()

load_dataset()

# %%
train_dir = '/content/brain-tumor-mri-dataset/Training'
test_dir = '/content/brain-tumor-mri-dataset/Testing'

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                    featurewise_center=False,
                                    samplewise_center=False,
                                    featurewise_std_normalization=False,
                                    samplewise_std_normalization=False,
                                    zca_whitening=False,
                                    rotation_range=0,
                                    zoom_range = 0,
                                    width_shift_range=0,
                                    height_shift_range=0,
                                    horizontal_flip=True,
                                    vertical_flip=False)

test_datagen = ImageDataGenerator(rescale=1./255,
                                   featurewise_center=False,
                                    samplewise_center=False,
                                    featurewise_std_normalization=False,
                                    samplewise_std_normalization=False,
                                    zca_whitening=False,
                                    rotation_range=0,
                                    zoom_range = 0,
                                    width_shift_range=0,
                                    height_shift_range=0,
                                    horizontal_flip=True,
                                    vertical_flip=False)



train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode= "categorical",
    # color_mode='grayscale'
    )

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode= "categorical",
    # color_mode='grayscale'
    )
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
base_model = tf.keras.applications.vgg16.VGG16(input_shape=(256,256,3), include_top=False, weights='imagenet')

# Set all layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False
# Set the last vgg block to trainable
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

model = Sequential()
model.add(Input(shape=(256,256,3)))
model.add(base_model)
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4, activation='softmax'))

model.compile(optimizer=Adam(learning_rate=0.0001),
             loss='categorical_crossentropy',
             metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dropout (Dropout)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 18909636 (72.13 MB)
# Trainable params: 11274372 (43.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
model_es = EarlyStopping(
    monitor = 'loss',
    min_delta = 1e-11,
    patience = 12,
    verbose = 1
    )

model_rlr = ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.2,
    patience = 6,
    verbose = 1
    )

model_mcp = ModelCheckpoint(
    filepath = 'VGG16_model_weights.h5',
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only = True,
    verbose = 1
    )

history = model.fit(
    train_generator,
    steps_per_epoch=5712//32,
    epochs=20,
    validation_data=test_generator,
    validation_steps= 1311//32,
    callbacks=[model_es, model_rlr, model_mcp]
    )
# Out:
# Epoch 1/20
# 178/178 [==============================] - ETA: 0s - loss: 0.4303 - accuracy: 0.8350
# Epoch 1: val_accuracy improved from -inf to 0.84922, saving model to VGG16_model_weights.h5
# 178/178 [==============================] - 63s 261ms/step - loss: 0.4303 - accuracy: 0.8350 - val_loss: 0.4525 - val_accuracy: 0.8492 - lr: 1.0000e-04
# Epoch 2/20
# 178/178 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9366
# Epoch 2: val_accuracy improved from 0.84922 to 0.93984, saving model to VGG16_model_weights.h5
# 178/178 [==============================] - 45s 253ms/step - loss: 0.1809 - accuracy: 0.9366 - val_loss: 0.1616 - val_accuracy: 0.9398 - lr: 1.0000e-04
# Epoch 3/20
# 178/178 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9623
# Epoch 3: val_accuracy improved from 0.93984 to 0.97500, saving model to VGG16_model_weights.h5
# 178/178 [==============================] - 44s 247ms/step - loss: 0.1041 - accuracy: 0.9623 - val_loss: 0.0709 - val_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 4/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9754
# Epoch 4: val_accuracy improved from 0.97500 to 0.97656, saving model to VGG16_model_weights.h5
# 178/178 [==============================] - 44s 249ms/step - loss: 0.0661 - accuracy: 0.9754 - val_loss: 0.0712 - val_accuracy: 0.9766 - lr: 1.0000e-04
# Epoch 5/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9808
# Epoch 5: val_accuracy did not improve from 0.97656
# 178/178 [==============================] - 41s 231ms/step - loss: 0.0588 - accuracy: 0.9808 - val_loss: 0.0825 - val_accuracy: 0.9664 - lr: 1.0000e-04
# Epoch 6/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9861
# Epoch 6: val_accuracy improved from 0.97656 to 0.98516, saving model to VGG16_model_weights.h5
# 178/178 [==============================] - 45s 251ms/step - loss: 0.0404 - accuracy: 0.9861 - val_loss: 0.0422 - val_accuracy: 0.9852 - lr: 1.0000e-04
# Epoch 7/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9833
# Epoch 7: val_accuracy improved from 0.98516 to 0.99297, saving model to VGG16_model_weights.h5
# 178/178 [==============================] - 44s 249ms/step - loss: 0.0489 - accuracy: 0.9833 - val_loss: 0.0281 - val_accuracy: 0.9930 - lr: 1.0000e-04
# Epoch 8/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9914
# Epoch 8: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 40s 225ms/step - loss: 0.0214 - accuracy: 0.9914 - val_loss: 0.0453 - val_accuracy: 0.9836 - lr: 1.0000e-04
# Epoch 9/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9910
# Epoch 9: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 44s 246ms/step - loss: 0.0306 - accuracy: 0.9910 - val_loss: 0.0459 - val_accuracy: 0.9844 - lr: 1.0000e-04
# Epoch 10/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9952
# Epoch 10: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 44s 246ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.0405 - val_accuracy: 0.9906 - lr: 1.0000e-04
# Epoch 11/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9961
# Epoch 11: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 44s 246ms/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.0673 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 12/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9974
# Epoch 12: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 45s 251ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0590 - val_accuracy: 0.9766 - lr: 1.0000e-04
# Epoch 13/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9961
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 13: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 44s 249ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.0620 - val_accuracy: 0.9812 - lr: 1.0000e-04
# Epoch 14/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9970
# Epoch 14: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 44s 249ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0364 - val_accuracy: 0.9914 - lr: 2.0000e-05
# Epoch 15/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 15: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 41s 229ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0310 - val_accuracy: 0.9922 - lr: 2.0000e-05
# Epoch 16/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9991
# Epoch 16: val_accuracy did not improve from 0.99297
# 178/178 [==============================] - 44s 245ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 0.0334 - val_accuracy: 0.9914 - lr: 2.0000e-05
# Epoch 17/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 17: val_accuracy improved from 0.99297 to 0.99375, saving model to VGG16_model_weights.h5
# 178/178 [==============================] - 45s 251ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0280 - val_accuracy: 0.9937 - lr: 2.0000e-05
# Epoch 18/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9991
# Epoch 18: val_accuracy did not improve from 0.99375
# 178/178 [==============================] - 40s 224ms/step - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.0261 - val_accuracy: 0.9930 - lr: 2.0000e-05
# Epoch 19/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9988
# Epoch 19: val_accuracy did not improve from 0.99375
# 178/178 [==============================] - 44s 246ms/step - loss: 0.0016 - accuracy: 0.9988 - val_loss: 0.0296 - val_accuracy: 0.9914 - lr: 2.0000e-05
# Epoch 20/20
# 178/178 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9991
# Epoch 20: val_accuracy did not improve from 0.99375
# 178/178 [==============================] - 44s 246ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0293 - val_accuracy: 0.9914 - lr: 2.0000e-05

# %%
# Evaluating the model
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples//32)
print(f"Test Loss: {loss:0.5f}")
print(f"Test Accuracy: {accuracy:0.5f}")
# Out:
# 40/40 [==============================] - 7s 162ms/step - loss: 0.0220 - accuracy: 0.9930
# Test Loss: 0.02203
# Test Accuracy: 0.99297

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('CNN Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('CNN Model Loss')

plt.tight_layout()
plt.show()

# %%
categories = ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
all_pred = []
all_true = []

# Assuming `test` is an image generator or a dataset generator
# Iterate through the generator to process all images
for i in range(41):  # Replace `total_iterations` with the actual number of iterations needed
    X_test, y_test = next(test_generator)
    pred = model.predict(X_test)

    pred = np.argmax(pred, axis=1)
    y_test_new = np.argmax(y_test, axis=1)

    # Append predictions and true labels to the respective lists
    all_pred.extend(pred)
    all_true.extend(y_test_new)

# Calculate the classification report using all predictions and true labels
clear_output()
print(classification_report(all_true, all_pred, target_names=categories))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       1.00      0.98      0.99       300
#   meningioma       0.98      0.99      0.99       306
#      notumor       1.00      1.00      1.00       405
#    pituitary       1.00      1.00      1.00       300
#
#     accuracy                           0.99      1311
#    macro avg       0.99      0.99      0.99      1311
# weighted avg       0.99      0.99      0.99      1311

# %%
conf_matrix = confusion_matrix(all_true, all_pred)
# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
